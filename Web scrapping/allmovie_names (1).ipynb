# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get('https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav')

# %%
soup = BeautifulSoup(req.content,"html.parser")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access "http://www.ambitionbox.com/list-of-companies?" on this server.<p>
# Reference #18.8ce954b8.1691996222.1bddaa25
# </p></body>
# </html>
# >

# %%
req = requests.get("https://www.lyricstape.com/movie-directory")

# %%
soup = BeautifulSoup(req.content,"html.parser")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <style type="text/css">
#
#   input[type="text"]:focus{
#      box-shadow: 0 0 0 rgb(255, 255, 255);
# }
# </style>
# <head>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <title> Telugu Song Lyrics | తెలుగు  సినీ  గీత  రచనలు
#   </title>
# <link href="https://www.lyricstape.com/assets/image/lyr_logo.png" rel="icon"/>
# <meta charset="utf-8"/>
# <meta content="Get all latest and best telugu movie song lyrics in Telugu. Platform which is built to provide telugu movie song lyrics in telugu." name="description"/>
# <meta content="Latest Telugu Movie Songs, Telugu movie songs, Telugu Songs, Lyrics, Telugu Lyrics, Telugu Song Lyrics" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://www.lyricstape.com/assets/bootstrap.min.css" rel="stylesheet"/>
# ...

# %%
soup.find_all("title")[0].text
# Out:
# ' Telugu Song Lyrics | తెలుగు  సినీ  గీత  రచనలు \n  '

# %%
len(soup.find_all('a'))
# Out:
# 850

# %%
for i in soup.find_all('a'):
    print (i.text.strip())
# Out:
# Home
# Latest Movies
# Movie Directory
# Lyricist
# EntertainmentZone
# Advertise With Us
# Adipurush
# Agent
# Amigos
# Baby
# Balagam
# Bholaa Shankar
# Bootcut Balaraju
# Bro
# Das Ka Dhamki
# Dasara
# Extra - Ordinary Man
# Gandeevadhari Arjuna
# Intinti Ramayanam
# Jailer
# Kushi
# Mem Famous
# Meter
# Miss Shetty Mr Polishetty
# Ooru Peru Bhairavakona
# Rama Banam
# Rangabali
# Rangamarthanda
# Ravanasura
# Rules Ranjann
# Samajavaragamana
# Shaakuntalam
# Sir
# Skanda
# Spy
# Tillu Square
# Veera Simha Reddy
# Vinaro Bhagyamu Vishnu Katha
# Virupaksha
# Waltair Veerayya
# Writer Padmabhushan
# 18 Pages
# Aa Ammayi Gurinchi Meeku Cheppali
# Aadavallu Meeku Joharlu
# Acharya
# Ante Sundaraniki
# Ashoka Vanamlo Arjuna Kalyanam
# Atithi Devo Bhava
# Bangarraju
# Bhala Thandhanana
# Bimbisara
# Chor Bazaar
# Dhamaka
# DJ Tillu
# F3
# Gandhari
# Ghani
# God Father
# Hero
# KGF 2
# Khiladi
# Kotha Kothaga
# Krishna Vrinda Vihari
# Liger
# Lollipop
# Macherla Niyojakavargam
# Major
# ...
